# %%
import pandas as pd
import sqlite3

df = pd.read_pickle("../data/Amazon_products.pkl")

# %%
conn = sqlite3.connect(":memory:")
df.to_sql("products", conn, index=False)
cursor = conn.cursor()

# Get the number of products in the dataset
cursor.execute("SELECT COUNT(*) FROM products")
print(cursor.fetchone())
# Out:
# (1242,)

# %%
def transform_to_dataframe(result):
    return pd.DataFrame(result, columns=[desc[0] for desc in cursor.description])

# %% [markdown]
# #### 1. Getting products that have price less than 100

# %%
query = "SELECT * FROM products WHERE price < 100"
# result = pd.read_sql_query(query, conn)
# result.head()
cursor.execute(query)
result = cursor.fetchall()
transform_to_dataframe(result).head()
# Out:
#          asin                                              title  price  \
# 0  B0CT4HX4T9  Lined Spiral Journal Notebook for Women & Men,...   5.99
# 1  B003O2RXUQ  Five Star Spiral Notebook + Study App, 5 Subje...   5.68
# 2  B00D3OR58A  Oxford Spiral Notebook 6 Pack, 1 Subject, Coll...  11.99
# 3  B00P9U2EM8  Mead Spiral Notebooks, 6 Pack, 1 Subject, Coll...  12.21
# 4  B01DN8TCEU  Amazon Basics Classic Lined Notebook, 240 Page...   6.39
#
#    list_price  rating  reviews  sold_past_month  is_bestseller  is_prime  \
# 0        7.99     4.7   1158.0          10000.0              0         0
# 1       11.99     4.8  30479.0           7000.0              1         0
# 2       12.81     4.8  42678.0           6000.0              0         0
# 3         NaN     4.7  16143.0          10000.0              0         0
# 4        8.54     4.7  46185.0           5000.0              0         0
#
#    is_amazon_choice  has_sustainability_features  available_offers  \
# 0                 1                            1               NaN
# 1                 0                            0               NaN
# 2                 0                            0               7.0
# 3                 0                            0              18.0
# 4                 0                            0               NaN
#
#   amazon_choice_type brand free_delivery_date fastest_delivery_date
# 0       Overall Pick  None               None                  None
# 1               None  None               None                  None
# 2               None  None               None                  None
# 3               None  None               None                  None
# 4               None  None               None                  None

# %% [markdown]
# #### 2. All products that are eligible for Amazon Prime and have an average rating of 4 or higher.

# %%
query = """
SELECT * FROM products
WHERE is_prime = 1 AND rating > 4
"""
cursor.execute(query)
result = cursor.fetchall()
transform_to_dataframe(result).head()
# Out:
#          asin                                              title  price  \
# 0  B07QGHK6Q8  Logitech G213 Prodigy Gaming Keyboard, LIGHTSY...  39.99
# 1  B06XW8QXVG  Perixx PERIBOARD-317 Wired Backlit USB Keyboar...  19.99
# 2  B08Z6X4NK3  Logitech G413 SE Full-Size Mechanical Gaming K...  57.06
# 3  B09STTTKBK  Arteck Backlit USB Wired Full Size Keyboard wi...  35.99
# 4  B0CZM6JKZ4  HP 400 Backlit Wired Keyboard (Ash Wired) - Wa...  39.99
#
#    list_price  rating  reviews  sold_past_month  is_bestseller  is_prime  \
# 0       69.99     4.5   6142.0           2000.0              0         1
# 1       29.90     4.4   8242.0            400.0              0         1
# 2       79.99     4.6   1668.0           1000.0              0         1
# 3         NaN     4.5   2473.0            500.0              0         1
# 4       49.99     4.4     34.0             50.0              0         1
#
#    is_amazon_choice  has_sustainability_features  available_offers  \
# 0                 1                            1               2.0
# 1                 0                            0               3.0
# 2                 0                            1               8.0
# 3                 0                            0               2.0
# 4                 0                            0               NaN
#
#   amazon_choice_type brand free_delivery_date fastest_delivery_date
# 0       Overall Pick  None        Tue, Nov 19                  None
# 1               None  None        Tue, Nov 19                  None
# 2               None  None        Tue, Nov 19                  None
# 3               None  None        Tue, Nov 19                  None
# 4               None  None        Tue, Nov 19                  None

# %% [markdown]
# #### 3. top 5 best-selling products (is_bestseller) sorted by the number of units sold in the past month.

# %%
query = """
SELECT * FROM products
WHERE is_bestseller = 1
ORDER BY sold_past_month DESC
LIMIT 5
"""
cursor.execute(query)
result = cursor.fetchall()
transform_to_dataframe(result).head()
# Out:
#          asin                                              title  price  \
# 0  B08BRCT4JH  BESIGN LS03 Aluminum Laptop Stand, Ergonomic D...  18.99
# 1  B09MQWWP87  Taygeer Travel Backpack for Women, Carry On Ba...  17.99
# 2  B0B1HJ666G  Mac Book Pro Charger - 118W USB C Charger Fast...  35.99
# 3  B09G9FPHY6  iPad (9th Generation): with A13 Bionic chip, 1...    NaN
# 4  B079JLY5M5  MK270 Wireless Keyboard And Mouse Combo For Wi...  29.99
#
#    list_price  rating  reviews  sold_past_month  is_bestseller  is_prime  \
# 0       24.99     4.8  18013.0          10000.0              1         0
# 1       23.99     4.7  10033.0          10000.0              1         0
# 2         NaN     4.4   4321.0          10000.0              1         0
# 3         NaN     4.8  70660.0          10000.0              1         0
# 4         NaN     4.5  97246.0          10000.0              1         1
#
#    is_amazon_choice  has_sustainability_features  available_offers  \
# 0                 0                            1               2.0
# 1                 0                            1               NaN
# 2                 0                            0               5.0
# 3                 0                            1               4.0
# 4                 0                            1               2.0
#
#   amazon_choice_type     brand free_delivery_date fastest_delivery_date
# 0               None      None               None                  None
# 1               None      None               None                  None
# 2               None      None               None                  None
# 3               None     Apple               None                  None
# 4               None  Logitech        Tue, Nov 19           Mon, Nov 18

# %%
conn.close()
